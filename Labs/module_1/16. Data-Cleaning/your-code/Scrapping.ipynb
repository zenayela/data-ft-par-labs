EAGgAPIAhgCIAEwAJ4AUgAqgBYAC4AGIAMwAcwBCACGgEQARIAowBSgCxAFuAMoAaIA1QBsgDvgH2AfoBFgCMAEcAJSAUMAq4BWwC5gF5ANoAbgA9ACLwEiAJsATsAocBTQCtgFigLYAXAAuQBdoDDQGHgMYAZEAyQBk4AAA.f_gAD_gAAAAA; __gads=ID=05a3b8de5a466d9d:T=1613471630:S=ALNI_MaF-YLuqIx-wAUT3DpNcpufWWtxCQ; _lm_id=GJD0JBOFJVXJMX0; _gid=GA1.2.1316810475.1613472435; _gcl_au=1.1.1744329584.1613472435; _fbp=fb.1.1613472435037.1509600016; __cf_bm=399ead662bbb6e679c45c2b39f75e62557897607-1613476872-1800-AdN6NWxqOl4aWU/squKYdzni1EmnxmV4MTcaQMKsOTpV6TN9XP/t57O8rHEc/WhvSpQKPfa863IsLNHoydXQYKu9IlAnItKh8tkygyBa90gXZKFHvWeJItOdP6iDykj3/YQEQ672hZwaR175g3no6K8zu1cXy6l5F/w0puatedBfrU1339sIgJ6GaQzQ5JXyRA==; feature.expose.ca6e2b81-07da-4d1f-b285-89d0134e4def=%5B%22sqp_ads%22%2C%22catalog_es_segment_boost_weight%22%2C%22nasa_delivery_instructions_redesign%22%5D; _gat=1; _vinted_fr_session=...%3D%3D--d1d9d50205b302c4f64316ad1e0b6c3481894391; _ga=GA1.1.80257146.1613472435; OptanonConsent=isIABGlobal=false&datestamp=Tue+Feb+16+2021+13%3A06%3A19+GMT%2B0100+(heure+normale+d%E2%80%99Europe+centrale)&version=6.12.0&hosts=&consentId=3546ce6a-1551-461d-b1df-fb17759ab419&interactionCount=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0002%3A1%2CC0003%3A1%2CC0004%3A1%2CSTACK42%3A1&geolocation=FR%3BIDF&AwaitingReconsent=false; _ga_ZJHK1N3D75=GS1.1.1613476871.2.1.1613477189.50
referer: https://www.vinted.fr/vetements?order=price_low_to_high&time=1613477178&page=2
sec-fetch-dest: empty
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Macintosh; Intel Mac OS X 11_2_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36
x-csrf-token: v9TxUIFKJrqKQkpKOeOefTUmMSaxNQx49eADp4+0gnJzHuwvwAxgw/RCyRuAVr6HjaohTZbJALNN18rBsXB4yQ="""

# %%
print(headers)
# Out:
# accept: application/json, text/plain, */*
# accept-encoding: gzip, deflate, br
# accept-language: fr
# ...

# %%
df=pd.DataFrame()
for i in range(5):
url='https://www.vinted.fr/api/v2/items?catalog_ids=&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&order=price_low_to_high&page=2&per_page=24&time=1613477178&search_session_id=fc64e6ee-2f55-4b42-be93-90a322a7bccd'
data=r.get(url, headers=headers).json()
data=pd.json_normalize(data['items'])
df=df.append(data)
# Out:
#   File "<ipython-input-6-c753b2b9be7f>", line 3
#     url='https://www.vinted.fr/api/v2/items?catalog_ids=&color_ids=&brand_ids=&size_ids=&material_ids=&status_ids=&country_ids=&city_ids=&is_for_swap=0&order=price_low_to_high&page=2&per_page=24&time=1613477178&search_session_id=fc64e6ee-2f55-4b42-be93-90a322a7bccd'
#     ^
# IndentationError: expected an indented block

# %%
resp=r.get(url, headers=headers).json()
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7ed19b70c134> in <module>
# ----> 1 resp=r.get(url, headers=headers).json()
#       2 data
#
# NameError: name 'r' is not defined

# %%
data.keys()
# Out:
# dict_keys(['items', 'item_scores_by_id', 'pagination', 'search_correlation_id', 'search_session_id', 'code'])

# %%
data["items"]
# Out:
# [{'id': 907553466,
#   'title': 'Meisjes shirt Hema 98/104',
#   'brand_id': 21059,
#   'size_id': 619,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 48544268,
#   'owner_id': None,
#   'country_id': 10,
#   'catalog_id': 1535,
#   'color1_id': 12,
#   'color2_id': 23,
#   'package_size_id': 1,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 0,
#   'view_count': 0,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-16T13:05:41+01:00',
#   'description': 'Amper gedragen',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '18-24 mois / 86-92 cm',
#   'brand': 'Hema',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
# ...

# %%
resp=r.get(url, headers=headers)
data2=resp.json()
data2["items"]
# Out:
# [{'id': 907553466,
#   'title': 'Meisjes shirt Hema 98/104',
#   'brand_id': 21059,
#   'size_id': 619,
#   'status_id': 2,
#   'disposal_conditions': 4,
#   'user_id': 48544268,
#   'owner_id': None,
#   'country_id': 10,
#   'catalog_id': 1535,
#   'color1_id': 12,
#   'color2_id': 23,
#   'package_size_id': 1,
#   'is_hidden': 0,
#   'is_reserved': 0,
#   'reserved_for_user_id': None,
#   'is_visible': 1,
#   'is_unisex': 0,
#   'is_closed': 0,
#   'is_admin_alerted': False,
#   'active_bid_count': 0,
#   'favourite_count': 0,
#   'view_count': 0,
#   'moderation_status': 0,
#   'last_push_up_at': '2021-02-16T13:05:41+01:00',
#   'description': 'Amper gedragen',
#   'package_size_standard': True,
#   'item_closing_action': None,
#   'related_catalog_ids': [],
#   'related_catalogs_enabled': False,
#   'size': '18-24 mois / 86-92 cm',
#   'brand': 'Hema',
#   'composition': '',
#   'extra_conditions': '',
#   'is_for_sell': True,
#   'is_for_swap': False,
# ...

# %%
import pandas as pd

# %%
pd.headers()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-be6088aaf5eb> in <module>
# ----> 1 pd.headers()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'headers'

# %%
pd.json_normalized(data['items']) #normalized = create a clean data frame from the json file
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-ab3e1c29de0a> in <module>
# ----> 1 pd.json_normalized(data['items']) #normalized = create a clean data frame from the json file
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'json_normalized'

# %% [markdown]
# In order to get the data from Resteful API based website, we follow the following steps:
# 1. Open the url
# 2. Inspect the page in the network tab
# 3. Go to the second page (usually allows to identify how the pagination works, since on the first page you don't have page=1)
# 4. Search for the linke that will headers to Python
# 5. Grab de the link and request headers to Python
# 6. Send request
# 7. Get the .json from exercise

# %% [markdown]
# More apis

# %%
import pandas as pd

# %%
url="https://jsonplaceholder.typicode.com/todos"

# %%
pd.json_normalize(r.get(url).json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0303fedc1308> in <module>
# ----> 1 pd.json_normalize(r.get(url).json())
#
# NameError: name 'r' is not defined

# %%
pd.json_normalize(r.get('https://api.github.com/events').json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b40d67fc22dd> in <module>
# ----> 1 pd.json_normalize(r.get('https://api.github.com/events').json())
#
# NameError: name 'r' is not defined
