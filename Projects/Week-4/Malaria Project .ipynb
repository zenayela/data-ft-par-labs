# %% [markdown]
# ## Malaria in Africa

# %%
#Libraries

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# %matplotlib inline

# %%
os.chdir('/Users/zenayela.soares/data-ft-par-labs/Projects')
malaria = pd.read_csv('DatasetAfricaMalaria.csv')

# %%
malaria
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# ...

# %%
malaria.iloc[1:2, :]
# Out:
#   Country Name  Year Country Code  \
# 1       Angola  2007          AGO
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 1                                             286.72
#
#    Malaria cases reported  \
# 1               1533485.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 1                                               18.0
#
#    Children with fever receiving antimalarial drugs (% of children under age 5 with fever)  \
# 1                                               29.8
#
#    Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)  \
# 1                                                1.5
#
#    People using safely managed drinking water services (% of population)  \
# 1                                                NaN
#
#    People using safely managed drinking water services, rural (% of rural population)  \
# 1                                                NaN
#
# ...

# %%
malaria.isna().sum()/malaria.shape[0]*100
# Out:
# Country Name                                                                                0.000000
# Year                                                                                        0.000000
# Country Code                                                                                0.000000
# Incidence of malaria (per 1,000 population at risk)                                         7.407407
# Malaria cases reported                                                                      7.407407
# Use of insecticide-treated bed nets (% of under-5 population)                              77.777778
# Children with fever receiving antimalarial drugs (% of children under age 5 with fever)    79.461279
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)      82.154882
# People using safely managed drinking water services (% of population)                      83.333333
# ...

# %%
malaria.columns
# Out:
# Index(['Country Name', 'Year', 'Country Code',
#        'Incidence of malaria (per 1,000 population at risk)',
#        'Malaria cases reported',
#        'Use of insecticide-treated bed nets (% of under-5 population)',
#        'Children with fever receiving antimalarial drugs (% of children under age 5 with fever)',
#        'Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)',
#        'People using safely managed drinking water services (% of population)',
#        'People using safely managed drinking water services, rural (% of rural population)',
#        'People using safely managed drinking water services, urban (% of urban population)',
#        'People using safely managed sanitation services (% of population)',
#        'People using safely managed sanitation services, rural (% of rural population)',
#        'People using safely managed sanitation services, urban  (% of urban population)',
# ...

# %%
malaria1 = malaria[['Country Name','Year','Malaria cases reported','Rural population (% of total population)',
         'Rural population growth (annual %)', 'Urban population (% of total population)',
         'Urban population growth (annual %)', 'People using at least basic drinking water services (% of population)',
         'People using at least basic drinking water services, rural (% of rural population)', 
         'People using at least basic drinking water services, urban (% of urban population)',
         'People using at least basic sanitation services (% of population)',
         'People using at least basic sanitation services, rural (% of rural population)',
         'People using at least basic sanitation services, urban  (% of urban population)',
        ]]

# %%
malaria1
# Out:
#      Country Name  Year  Malaria cases reported  \
# 0         Algeria  2007                    26.0
# 1          Angola  2007               1533485.0
# 2           Benin  2007                     0.0
# 3        Botswana  2007                   390.0
# 4    Burkina Faso  2007                 44246.0
# ..            ...   ...                     ...
# 589          Togo  2017               1755577.0
# 590       Tunisia  2017                     NaN
# 591        Uganda  2017              11667831.0
# 592        Zambia  2017               5505639.0
# 593      Zimbabwe  2017                467508.0
#
#      Rural population (% of total population)  \
# 0                                       34.65
# 1                                       42.48
# 2                                       58.44
# 3                                       42.07
# 4                                       77.00
# ..                                        ...
# 589                                     58.84
# ...

# %%
malaria1.fillna(0)
# Out:
#      Country Name  Year  Malaria cases reported  \
# 0         Algeria  2007                    26.0
# 1          Angola  2007               1533485.0
# 2           Benin  2007                     0.0
# 3        Botswana  2007                   390.0
# 4    Burkina Faso  2007                 44246.0
# ..            ...   ...                     ...
# 589          Togo  2017               1755577.0
# 590       Tunisia  2017                     0.0
# 591        Uganda  2017              11667831.0
# 592        Zambia  2017               5505639.0
# 593      Zimbabwe  2017                467508.0
#
#      Rural population (% of total population)  \
# 0                                       34.65
# 1                                       42.48
# 2                                       58.44
# 3                                       42.07
# 4                                       77.00
# ..                                        ...
# 589                                     58.84
# ...

# %%
test = malaria1.groupby(['Country Name', 'Year', 'Malaria cases reported']).agg(sum)
test
# Out:
#                                                         index  \
# Country Name             Year   Malaria cases reported
# Algeria                  2012.0 8.545455e+00                0
# Angola                   2012.0 2.184926e+06                1
# Benin                    2012.0 7.799745e+05                2
# Botswana                 2012.0 7.960000e+02                3
# Burkina Faso             2012.0 3.781997e+06                4
# Burundi                  2012.0 3.659065e+06                5
# Cabo Verde               2012.0 6.354545e+01                6
# Cameroon                 2012.0 3.976025e+05                7
# Central African Republic 2012.0 2.328419e+05                8
# Chad                     2012.0 5.634647e+05                9
# Comoros                  2012.0 2.627418e+04               10
# Congo, Dem. Rep.         2012.0 7.050502e+06               11
# Congo, Rep.              2012.0 8.475382e+04               12
# ...

# %%
malaria1 = malaria1.groupby('Country Name').sum()/11

# %%
malaria1
# Out:
#                             Year  Malaria cases reported  \
# Country Name
# Algeria                   2012.0            8.545455e+00
# Angola                    2012.0            2.184926e+06
# Benin                     2012.0            7.799745e+05
# Botswana                  2012.0            7.960000e+02
# Burkina Faso              2012.0            3.781997e+06
# Burundi                   2012.0            3.659065e+06
# Cabo Verde                2012.0            6.354545e+01
# Cameroon                  2012.0            3.976025e+05
# Central African Republic  2012.0            2.328419e+05
# Chad                      2012.0            5.634647e+05
# Comoros                   2012.0            2.627418e+04
# Congo, Dem. Rep.          2012.0            7.050502e+06
# Congo, Rep.               2012.0            8.475382e+04
# Cote d'Ivoire             2012.0            1.634394e+06
# Djibouti                  2012.0            5.610727e+03
# ...

# %%
malaria1.round(2)
# Out:
#                             Year  Malaria cases reported  \
# Country Name
# Algeria                   2012.0                    8.55
# Angola                    2012.0              2184925.64
# Benin                     2012.0               779974.55
# Botswana                  2012.0                  796.00
# Burkina Faso              2012.0              3781996.64
# Burundi                   2012.0              3659064.91
# Cabo Verde                2012.0                   63.55
# Cameroon                  2012.0               397602.55
# Central African Republic  2012.0               232841.91
# Chad                      2012.0               563464.73
# Comoros                   2012.0                26274.18
# Congo, Dem. Rep.          2012.0              7050502.18
# Congo, Rep.               2012.0                84753.82
# Cote d'Ivoire             2012.0              1634394.45
# Djibouti                  2012.0                 5610.73
# ...

# %%
malaria1.columns
# Out:
# Index(['Year', 'Malaria cases reported',
#        'Rural population (% of total population)',
#        'Rural population growth (annual %)',
#        'Urban population (% of total population)',
#        'Urban population growth (annual %)',
#        'People using at least basic drinking water services (% of population)',
#        'People using at least basic drinking water services, rural (% of rural population)',
#        'People using at least basic drinking water services, urban (% of urban population)',
#        'People using at least basic sanitation services (% of population)',
#        'People using at least basic sanitation services, rural (% of rural population)',
#        'People using at least basic sanitation services, urban  (% of urban population)'],
#       dtype='object')

# %%
malaria2 = malaria1[['Malaria cases reported',
       'Rural population (% of total population)',
       'Rural population growth (annual %)',
       'Urban population (% of total population)',
       'Urban population growth (annual %)',
       'People using at least basic drinking water services (% of population)',
       'People using at least basic drinking water services, rural (% of rural population)',
       'People using at least basic drinking water services, urban (% of urban population)',
       'People using at least basic sanitation services (% of population)',
       'People using at least basic sanitation services, rural (% of rural population)',
       'People using at least basic sanitation services, urban  (% of urban population)']]

# %%
malaria2
# Out:
#                           Malaria cases reported  \
# Country Name
# Algeria                             8.545455e+00
# Angola                              2.184926e+06
# Benin                               7.799745e+05
# Botswana                            7.960000e+02
# Burkina Faso                        3.781997e+06
# Burundi                             3.659065e+06
# Cabo Verde                          6.354545e+01
# Cameroon                            3.976025e+05
# Central African Republic            2.328419e+05
# Chad                                5.634647e+05
# Comoros                             2.627418e+04
# Congo, Dem. Rep.                    7.050502e+06
# Congo, Rep.                         8.475382e+04
# Cote d'Ivoire                       1.634394e+06
# Djibouti                            5.610727e+03
# Egypt, Arab Rep.                    0.000000e+00
# Equatorial Guinea                   3.062045e+04
# Eritrea                             2.789782e+04
# ...

# %%
malaria3 = malaria2.sort_values(by='Malaria cases reported', ascending=False)

# %%
malaria3.round(2)
# Out:
#                           Malaria cases reported  \
# Country Name
# Congo, Dem. Rep.                      7050502.18
# Mozambique                            3998559.82
# Burkina Faso                          3781996.64
# Uganda                                3738748.18
# Burundi                               3659064.91
# Nigeria                               3642415.45
# Ghana                                 2546209.91
# Tanzania                              2207553.45
# Angola                                2184925.64
# Malawi                                1767785.45
# Niger                                 1715155.36
# Zambia                                1692651.45
# Cote d'Ivoire                         1634394.45
# Rwanda                                1590747.00
# Kenya                                 1577622.82
# Ethiopia                              1478788.09
# Liberia                               1112456.91
# Mali                                  1100568.82
# ...

# %%
malaria3.head(5)
# Out:
#                   Malaria cases reported  \
# Country Name
# Congo, Dem. Rep.            7.050502e+06
# Mozambique                  3.998560e+06
# Burkina Faso                3.781997e+06
# Uganda                      3.738748e+06
# Burundi                     3.659065e+06
#
#                   Rural population (% of total population)  \
# Country Name
# Congo, Dem. Rep.                                 58.880909
# Mozambique                                       67.130909
# Burkina Faso                                     74.191818
# Uganda                                           79.527273
# Burundi                                          88.769091
#
#                   Rural population growth (annual %)  \
# Country Name
# Congo, Dem. Rep.                            2.396364
# Mozambique                                  2.074545
# Burkina Faso                                2.197273
# Uganda                                      2.660909
# ...

# %%
malaria4 = malaria3.head(5)

# %%
malaria4
# Out:
#                   Malaria cases reported  \
# Country Name
# Congo, Dem. Rep.            7.050502e+06
# Mozambique                  3.998560e+06
# Burkina Faso                3.781997e+06
# Uganda                      3.738748e+06
# Burundi                     3.659065e+06
#
#                   Rural population (% of total population)  \
# Country Name
# Congo, Dem. Rep.                                 58.880909
# Mozambique                                       67.130909
# Burkina Faso                                     74.191818
# Uganda                                           79.527273
# Burundi                                          88.769091
#
#                   Rural population growth (annual %)  \
# Country Name
# Congo, Dem. Rep.                            2.396364
# Mozambique                                  2.074545
# Burkina Faso                                2.197273
# Uganda                                      2.660909
# ...

# %%
malaria4.round(2)
# Out:
#                   Malaria cases reported  \
# Country Name
# Congo, Dem. Rep.              7050502.18
# Mozambique                    3998559.82
# Burkina Faso                  3781996.64
# Uganda                        3738748.18
# Burundi                       3659064.91
#
#                   Rural population (% of total population)  \
# Country Name
# Congo, Dem. Rep.                                     58.88
# Mozambique                                           67.13
# Burkina Faso                                         74.19
# Uganda                                               79.53
# Burundi                                              88.77
#
#                   Rural population growth (annual %)  \
# Country Name
# Congo, Dem. Rep.                                2.40
# Mozambique                                      2.07
# Burkina Faso                                    2.20
# Uganda                                          2.66
# ...

# %%
malaria5 = malaria4.head(5)

# %%
malaria5
# Out:
#                   Malaria cases reported  \
# Country Name
# Congo, Dem. Rep.            7.050502e+06
# Mozambique                  3.998560e+06
# Burkina Faso                3.781997e+06
# Uganda                      3.738748e+06
# Burundi                     3.659065e+06
#
#                   Rural population (% of total population)  \
# Country Name
# Congo, Dem. Rep.                                 58.880909
# Mozambique                                       67.130909
# Burkina Faso                                     74.191818
# Uganda                                           79.527273
# Burundi                                          88.769091
#
#                   Rural population growth (annual %)  \
# Country Name
# Congo, Dem. Rep.                            2.396364
# Mozambique                                  2.074545
# Burkina Faso                                2.197273
# Uganda                                      2.660909
# ...

# %%
# %config InlineBackend.figure.format = 'png'
fig=plt.figure(figsize=(50,30))
malaria5['Malaria cases reported'].plot.bar('bo--', label='all_number', color=['maroon'], fontsize=40)
plt.title('Top 5 of Countries - Malaria', fontsize=60)
plt.xlabel('Countries', fontsize=40)
plt.ylabel('Average of Malaria cases in 10 years(by millions)', fontsize=40)
plt.grid()
plt.legend(loc=2, prop={'size': 20})
plt.show()
plt.savefig("out.png")

# %%
malaria1.reset_index(inplace=True)

# %%
malaria1
# Out:
#     index              Country Name    Year  Malaria cases reported  \
# 0       0                   Algeria  2012.0            8.545455e+00
# 1       1                    Angola  2012.0            2.184926e+06
# 2       2                     Benin  2012.0            7.799745e+05
# 3       3                  Botswana  2012.0            7.960000e+02
# 4       4              Burkina Faso  2012.0            3.781997e+06
# 5       5                   Burundi  2012.0            3.659065e+06
# 6       6                Cabo Verde  2012.0            6.354545e+01
# 7       7                  Cameroon  2012.0            3.976025e+05
# 8       8  Central African Republic  2012.0            2.328419e+05
# 9       9                      Chad  2012.0            5.634647e+05
# 10     10                   Comoros  2012.0            2.627418e+04
# 11     11          Congo, Dem. Rep.  2012.0            7.050502e+06
# 12     12               Congo, Rep.  2012.0            8.475382e+04
# ...

# %%
malaria1[(malaria1['Country Name']=='Congo, Dem. Rep.') & (malaria1.Year > 2007)]
# Out:
#     index      Country Name    Year  Malaria cases reported  \
# 11     11  Congo, Dem. Rep.  2012.0            7.050502e+06
#
#     Rural population (% of total population)  \
# 11                                 58.880909
#
#     Rural population growth (annual %)  \
# 11                            2.396364
#
#     Urban population (% of total population)  \
# 11                                 41.119091
#
#     Urban population growth (annual %)  \
# 11                            4.621818
#
#     People using at least basic drinking water services (% of population)  \
# 11                                          40.633636
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 11                                              20.87
#
#     People using at least basic drinking water services, urban (% of urban population)  \
# 11                                          68.981818
#
# ...

# %%
test.reset_index(inplace=True)

# %%
test[test['Country Name']=='Congo, Dem. Rep.']
# Out:
#         Country Name    Year  Malaria cases reported  index  \
# 11  Congo, Dem. Rep.  2012.0            7.050502e+06     11
#
#     Rural population (% of total population)  \
# 11                                 58.880909
#
#     Rural population growth (annual %)  \
# 11                            2.396364
#
#     Urban population (% of total population)  \
# 11                                 41.119091
#
#     Urban population growth (annual %)  \
# 11                            4.621818
#
#     People using at least basic drinking water services (% of population)  \
# 11                                          40.633636
#
#     People using at least basic drinking water services, rural (% of rural population)  \
# 11                                              20.87
#
#     People using at least basic drinking water services, urban (% of urban population)  \
# 11                                          68.981818
#
# ...

# %%
malaria
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# ...

# %%
congo = malaria[(malaria['Country Name']=='Congo, Dem. Rep.') & (malaria.Year)] 
congo
# Out:
#          Country Name  Year Country Code  \
# 11   Congo, Dem. Rep.  2007          COD
# 119  Congo, Dem. Rep.  2009          COD
# 227  Congo, Dem. Rep.  2011          COD
# 335  Congo, Dem. Rep.  2013          COD
# 443  Congo, Dem. Rep.  2015          COD
# 551  Congo, Dem. Rep.  2017          COD
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 11                                              481.93
# 119                                             452.18
# 227                                             399.59
# 335                                             327.62
# 443                                             308.83
# 551                                             329.13
#
#      Malaria cases reported  \
# 11                 740858.0
# 119               1879694.0
# 227               4561981.0
# 335               6719887.0
# 443              12538805.0
# 551              16793002.0
#
#      Use of insecticide-treated bed nets (% of under-5 population)  \
# ...

# %%
congo1 = congo[['Year','Malaria cases reported',
       'Rural population (% of total population)',
       'Rural population growth (annual %)',
       'Urban population (% of total population)',
       'Urban population growth (annual %)',
       'People using at least basic drinking water services (% of population)',
       'People using at least basic drinking water services, rural (% of rural population)',
       'People using at least basic drinking water services, urban (% of urban population)',
       'People using at least basic sanitation services (% of population)',
       'People using at least basic sanitation services, rural (% of rural population)',
       'People using at least basic sanitation services, urban  (% of urban population)']]

# %%
congo1
# Out:
#      Year  Malaria cases reported  Rural population (% of total population)  \
# 11   2007                740858.0                                     61.53
# 119  2009               1879694.0                                     60.51
# 227  2011               4561981.0                                     59.46
# 335  2013               6719887.0                                     58.37
# 443  2015              12538805.0                                     57.26
# 551  2017              16793002.0                                     56.12
#
#      Rural population growth (annual %)  \
# 11                                 2.45
# 119                                2.47
# 227                                2.45
# 335                                2.40
# 443                                2.33
# 551                                2.24
#
#      Urban population (% of total population)  \
# 11                                      38.47
# 119                                     39.49
# ...

# %%
import seaborn as sns

# %%
fig=plt.figure(figsize=(12,6))
plt.plot(congo1,'bo--', label='cases')
plt.title('Malaria in Congo Democratic Republic')
plt.xlabel('Number cases')
plt.ylabel('Years')
plt.grid()
#plt.axis('off')
plt.xticks(rotation=90)
plt.legend()
plt.show()

plt.plot(congo1,'bo--', label='cases')

# %%
sns.scatterplot(data=congo1, x='Year', y='Malaria cases reported', color=['maroon'])
plt.title('Malaria in Congo Dem. Republic')
plt.show()
plt.savefig("out.png")

# %%
congo3 = congo.groupby('Year')[['Malaria cases reported']].mean()

# %%
plt.plot(congo1['Year']);
plt.plot(congo1['Malaria cases reported']);
plt.show()

# %%
malaria
# Out:
#      Country Name  Year Country Code  \
# 0         Algeria  2007          DZA
# 1          Angola  2007          AGO
# 2           Benin  2007          BEN
# 3        Botswana  2007          BWA
# 4    Burkina Faso  2007          BFA
# ..            ...   ...          ...
# 589          Togo  2017          TGO
# 590       Tunisia  2017          TUN
# 591        Uganda  2017          UGA
# 592        Zambia  2017          ZMB
# 593      Zimbabwe  2017          ZWE
#
#      Incidence of malaria (per 1,000 population at risk)  \
# 0                                                 0.01
# 1                                               286.72
# 2                                               480.24
# 3                                                 1.03
# 4                                               503.80
# ..                                                 ...
# 589                                             278.20
# 590                                                NaN
# ...

# %%
malaria6 = malaria[['Country Name', 'Year','Malaria cases reported',
       'Rural population (% of total population)',
       'Rural population growth (annual %)',
       'Urban population (% of total population)',
       'Urban population growth (annual %)',
       'People using at least basic drinking water services (% of population)',
       'People using at least basic drinking water services, rural (% of rural population)',
       'People using at least basic drinking water services, urban (% of urban population)',
       'People using at least basic sanitation services (% of population)',
       'People using at least basic sanitation services, rural (% of rural population)',
       'People using at least basic sanitation services, urban  (% of urban population)', 'latitude', 'longitude', 'geometry']]

# %%
malaria6
# Out:
#      Country Name  Year  Malaria cases reported  \
# 0         Algeria  2007                    26.0
# 1          Angola  2007               1533485.0
# 2           Benin  2007                     0.0
# 3        Botswana  2007                   390.0
# 4    Burkina Faso  2007                 44246.0
# ..            ...   ...                     ...
# 589          Togo  2017               1755577.0
# 590       Tunisia  2017                     NaN
# 591        Uganda  2017              11667831.0
# 592        Zambia  2017               5505639.0
# 593      Zimbabwe  2017                467508.0
#
#      Rural population (% of total population)  \
# 0                                       34.65
# 1                                       42.48
# 2                                       58.44
# 3                                       42.07
# 4                                       77.00
# ..                                        ...
# 589                                     58.84
# ...
