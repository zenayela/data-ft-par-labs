# %% [markdown]
# ## La Centrale

# %%
import pandas as pd
import requests as r 
from bs4 import BeautifulSoup

# %%
url='https://www.lacentrale.fr/listing?makesModelsCommercialNames=AUDI%3AA1&options='

# %%
r.get(url)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.get(url).content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="fr"><head>
# <meta charset="utf-8"/>
# <script crossorigin="" src="https://www.lacentrale.fr/static/fragment-mozart/2.3.6-require.js"></script>
# ...

# %%
import time 
time.sleep(1000)
